# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Your code goes here
import initial_check as ch
import pandas as pd

# %load_ext autoreload
# %autoreload 2

# %%
url1 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv"
url2 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv"
url3 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv"

data1 = pd.read_csv(url1)
data2 = pd.read_csv(url2)
data3 = pd.read_csv(url3)

# %%
print(data1.shape)
data1.head()
# Out:
# (4008, 11)
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
ch.check(data1)
# Out:
# Number of columns: 11 amd rows: 4008
#
# Data types:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# dtype: object
#
# Unique values count:
# Customer                     1071
# ST                              8
# GENDER                          5
# Education                       6
# Customer Lifetime Value      1027
# Income                        774
# Monthly Premium Auto          132
# Number of Open Complaints       6
# Policy Type                     3
# Vehicle Class                   6
# Total Claim Amount            761
# dtype: int64
#
# This columns apear to be categroical:
# ...

# %%
ch.snake_f(data1)
ch.replace_col(data1, "gender", ['Femal', "female"], 'F')
ch.replace_col(data1, "gender", ['Male'], 'M')
ch.replace_col(data1, "state", ['AZ'], 'ArizonaF')
ch.replace_col(data1, "state", ['Cali'], 'California')
ch.replace_col(data1, "state", ['WA'], 'Washington')
ch.replace_col(data1, "education", ['Bachelors'], 'Bachelor')
ch.in_col_replace(data1, "customer_lifetime_value", '%', "", "float")

ch.drop(data1)
ch.filling_nan(data1, "gender", "mode")
ch.format_complain(data1, 'number_of_open_complaints')
data1 = ch.drop_nan(data1)

# %%
ch.check(data1)
# Out:
# Number of columns: 11 amd rows: 1068
#
# Data types:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints    float64
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object
#
# Unique values count:
# customer                     1068
# state                           6
# gender                          2
# education                       5
# customer_lifetime_value      1027
# income                        772
# monthly_premium_auto          131
# number_of_open_complaints       6
# policy_type                     3
# vehicle_class                   6
# total_claim_amount            758
# dtype: int64
#
# This columns apear to be categroical:
# ...

# %%
data1.head(10)
# Out:
#    customer       state gender             education  customer_lifetime_value  \
# 1   QZ44356     Arizona      F              Bachelor                697953.59
# 2   AI49188      Nevada      F              Bachelor               1288743.17
# 3   WW63253  California      M              Bachelor                764586.18
# 4   GA49547  Washington      M  High School or Below                536307.65
# 5   OC83172      Oregon      F              Bachelor                825629.78
# 6   XZ87318      Oregon      F               College                538089.86
# 7   CF85061     Arizona      M                Master                721610.03
# 8   DY87989      Oregon      M              Bachelor               2412750.40
# 9   BQ94931      Oregon      F               College                738817.81
# 10  SX51350  California      M               College                473899.20
#
#      income  monthly_premium_auto  number_of_open_complaints     policy_type  \
# ...

# %%
print(data2.shape)
data2.head()
# Out:
# (996, 11)
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# ...

# %%
ch.check(data2)
# Out:
# Number of columns: 11 amd rows: 996
#
# Data types:
# Customer                      object
# ST                            object
# GENDER                        object
# Education                     object
# Customer Lifetime Value       object
# Income                         int64
# Monthly Premium Auto           int64
# Number of Open Complaints     object
# Total Claim Amount           float64
# Policy Type                   object
# Vehicle Class                 object
# dtype: object
#
# Unique values count:
# Customer                     996
# ST                             6
# GENDER                         4
# Education                      6
# Customer Lifetime Value      950
# Income                       733
# Monthly Premium Auto         126
# Number of Open Complaints      6
# Total Claim Amount           667
# Policy Type                    3
# Vehicle Class                  6
# dtype: int64
#
# This columns apear to be categroical:
# ...

# %%
ch.snake_f(data2)
ch.replace_col(data2, "gender", ['Femal', "female"], 'F')
ch.replace_col(data2, "gender", ['Male'], 'M')
ch.replace_col(data2, "state", ['AZ'], 'ArizonaF')
ch.replace_col(data2, "state", ['Cali'], 'California')
ch.replace_col(data2, "state", ['WA'], 'Washington')
ch.replace_col(data2, "education", ['Bachelors'], 'Bachelor')
ch.in_col_replace(data2, "customer_lifetime_value", '%', "", "float")

ch.drop(data2)
ch.filling_nan(data2, "gender", "mode")
ch.format_complain(data2, 'number_of_open_complaints')
data2 = ch.drop_nan(data2)

# %%
ch.check(data2)
# Out:
# Number of columns: 11 amd rows: 992
#
# Data types:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                         int64
# monthly_premium_auto           int64
# number_of_open_complaints      int64
# total_claim_amount           float64
# policy_type                   object
# vehicle_class                 object
# dtype: object
#
# Unique values count:
# customer                     992
# state                          6
# gender                         2
# education                      5
# customer_lifetime_value      950
# income                       730
# monthly_premium_auto         126
# number_of_open_complaints      6
# total_claim_amount           666
# policy_type                    3
# vehicle_class                  6
# dtype: int64
#
# This columns apear to be categroical:
# ...

# %%
data2.head(10)
# Out:
#   customer       state gender education  customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor                323912.47   16061
# 1  CW49887  California      F    Master                462680.11   79487
# 2  MY31220  California      F   College                899704.02   54230
# 3  UH35128      Oregon      F   College               2580706.30   71210
# 4  WH52799     Arizona      F   College                380812.21   94903
# 5  WL99637     Arizona      M  Bachelor                761413.80   27293
# 6  UC84059  California      F    Master                689845.53   70950
# 7  HW62747      Oregon      M   College                229837.92       0
# 8  BH11344      Oregon      F    Doctor                280669.61   37009
# 9  TX28465      Nevada      M   College                520611.82   52629
#
#    monthly_premium_auto  number_of_open_complaints  total_claim_amount  \
# 0                    88                          0          633.600000
# ...

# %%
data3.head(10)
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
# 5  VI78454     Arizona              2750.705045               College      M
# 6  FP59138      Oregon             13024.130120                Master      M
# 7  XN62489      Oregon              2538.626320              Bachelor      M
# 8  GP66031  California              2585.955652               College      F
# 9  IX68587      Nevada              5096.673223                Master      F
#
#    Income  Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# ...

# %%
ch.check(data3)
# Out:
# Number of columns: 11 amd rows: 7070
#
# Data types:
# Customer                      object
# State                         object
# Customer Lifetime Value      float64
# Education                     object
# Gender                        object
# Income                         int64
# Monthly Premium Auto           int64
# Number of Open Complaints      int64
# Policy Type                   object
# Total Claim Amount           float64
# Vehicle Class                 object
# dtype: object
#
# Unique values count:
# Customer                     7070
# State                           5
# Customer Lifetime Value      6288
# Education                       5
# Gender                          2
# Income                       4463
# Monthly Premium Auto          194
# Number of Open Complaints       6
# Policy Type                     3
# Total Claim Amount           4025
# Vehicle Class                   6
# dtype: int64
#
# This columns apear to be categroical:
# ...

# %%
ch.snake_f(data3)
#ch.replace_col(data3, "gender", ['Femal', "female"], 'F')
#ch.replace_col(data3, "gender", ['Male'], 'M')
#ch.replace_col(data3, "state", ['AZ'], 'ArizonaF')
#ch.replace_col(data3, "state", ['Cali'], 'California')
#ch.replace_col(data3, "state", ['WA'], 'Washington')
#ch.replace_col(data3, "education", ['Bachelors'], 'Bachelor')
#ch.in_col_replace(data3, "customer_lifetime_value", '%', "", "float")

#ch.drop(data3)
#ch.filling_nan(data3, "gender", "mode")
#ch.format_complain(data3, 'number_of_open_complaints')
#data3 = ch.drop_nan(data3)

# %%
ch.check(data3)
# Out:
# Number of columns: 11 amd rows: 7070
#
# Data types:
# customer                      object
# state                         object
# customer_lifetime_value      float64
# education                     object
# gender                        object
# income                         int64
# monthly_premium_auto           int64
# number_of_open_complaints      int64
# policy_type                   object
# total_claim_amount           float64
# vehicle_class                 object
# dtype: object
#
# Unique values count:
# customer                     7070
# state                           5
# customer_lifetime_value      6288
# education                       5
# gender                          2
# income                       4463
# monthly_premium_auto          194
# number_of_open_complaints       6
# policy_type                     3
# total_claim_amount           4025
# vehicle_class                   6
# dtype: int64
#
# This columns apear to be categroical:
# ...

# %%
data3.head(10)
# Out:
#   customer       state  customer_lifetime_value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
# 5  VI78454     Arizona              2750.705045               College      M
# 6  FP59138      Oregon             13024.130120                Master      M
# 7  XN62489      Oregon              2538.626320              Bachelor      M
# 8  GP66031  California              2585.955652               College      F
# 9  IX68587      Nevada              5096.673223                Master      F
#
#    income  monthly_premium_auto  number_of_open_complaints     policy_type  \
# ...

# %%
data = pd.concat([data1, data2, data3], sort = False)
data
# Out:
#      customer       state gender             education  \
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 1                6.979536e+05      0.0                  94.0
# 2                1.288743e+06  48767.0                 108.0
# 3                7.645862e+05      0.0                 106.0
# ...

# %%
ch.check(data)
# Out:
# Number of columns: 11 amd rows: 9130
#
# Data types:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints    float64
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object
#
# Unique values count:
# customer                     9053
# state                           6
# gender                          2
# education                       5
# customer_lifetime_value      8211
# income                       5653
# monthly_premium_auto          208
# number_of_open_complaints       6
# policy_type                     3
# vehicle_class                   6
# total_claim_amount           5067
# dtype: int64
#
# This columns apear to be categroical:
# ...

# %%
ch.drop(data)
ch.check(data)
# Out:
# Number of columns: 11 amd rows: 9127
#
# Data types:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints    float64
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object
#
# Unique values count:
# customer                     9053
# state                           6
# gender                          2
# education                       5
# customer_lifetime_value      8211
# income                       5653
# monthly_premium_auto          208
# number_of_open_complaints       6
# policy_type                     3
# vehicle_class                   6
# total_claim_amount           5067
# dtype: int64
#
# This columns apear to be categroical:
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here

url4 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv"
data4 = pd.read_csv(url4)

# %%
print(data4.shape)
data4.head()
# Out:
# (10910, 27)
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %%
ch.check(data4)
# Out:
# Number of columns: 27 amd rows: 10910
#
# Data types:
# unnamed:_0                         int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# ...

# %%
data4.effective_to_date = pd.to_datetime(data4.effective_to_date)
data4.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %%
ch.check(data4)
# Out:
# Number of columns: 27 amd rows: 10910
#
# Data types:
# unnamed:_0                                int64
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints               float64
# number_of_policies                        int64
# ...

# %%
data4 = ch.drop_col(data4,"unnamed:_0")

# %%
data4
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
value_to_remove = 0.384256
data4 = data4[~data4['number_of_open_complaints'].between(value_to_remove - 1e-6, value_to_remove + 1e-6)]
data4
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 5      HO81102  California              4745.181764       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#                   education effective_to_date employmentstatus gender  income  \
# ...

# %%
ch.check(data4)
# Out:
# Number of columns: 26 amd rows: 10277
#
# Data types:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints               float64
# number_of_policies                        int64
# policy_type                              object
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
pivot_table = data4.pivot_table(values='customer_lifetime_value', index='sales_channel', aggfunc='sum').round(2)
pivot_table
# Out:
#                customer_lifetime_value
# sales_channel
# Agent                      31163203.53
# Branch                     23241909.58
# Call Center                16229622.96
# Web                        11894746.62

# %%
# Agent: The agents has the highest total revenue, which suggests it is the most successful sales channel in terms of total revenue.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
pivot_table = data4.pivot_table(values='customer_lifetime_value', index='sales_channel', columns="gender", aggfunc='mean').round(2)
pivot_table
# Out:
# gender               F        M
# sales_channel
# Agent          7944.88  8090.26
# Branch         8118.24  8072.20
# Call Center    8434.19  7796.35
# Web            7856.45  7776.40

# %%
# The highest avergae life time value for males is coming from agents, while for females is from the call centers

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes 
df_long = data4.groupby(['month', 'policy_type'])['number_of_open_complaints'].sum().reset_index()
df_long
# Out:
#    month     policy_type  number_of_open_complaints
# 0      1  Corporate Auto                      415.0
# 1      1   Personal Auto                     1635.0
# 2      1    Special Auto                       84.0
# 3      2  Corporate Auto                      361.0
# 4      2   Personal Auto                     1363.0
# 5      2    Special Auto                       91.0

# %%
df_long_ord = df_long.sort_values(by='number_of_open_complaints', ascending=False)
df_long_ord
# Out:
#    month     policy_type  number_of_open_complaints
# 1      1   Personal Auto                     1635.0
# 4      2   Personal Auto                     1363.0
# 0      1  Corporate Auto                      415.0
# 3      2  Corporate Auto                      361.0
# 5      2    Special Auto                       91.0
# 2      1    Special Auto                       84.0
